# %% [markdown]
# # Задание 1.1

# %%
import pandas as pd
df=pd.read_excel('DATA.xlsx',sheet=0,index='Date')

# %% [markdown]
# # Задание 1.2

# %%
if df['Date'].dtype=='<M8[ns]' or df['Date'].dtype=='datetime64[ns]' :
    print df['Date'].dtype
else:
    pd.to_datetime(df['Date'])
    print df['Date'].dtype
# Out:
# datetime64[ns]

# %% [markdown]
# # Задание 1.3

# %%
print df['Date'].dt.date.min()
print df['Date'].dt.date.max()
print (df['Date'].dt.date.max()-df['Date'].dt.date.min())
# Out:
# 2013-06-22
# 2017-06-21
# 1460 days, 0:00:00

# %% [markdown]
# # Задание 1.4

# %%
import matplotlib
from matplotlib import pyplot as plt
df.plot(x='Date',figsize=(22,11))
plt.show()

# %% [markdown]
# # Задание 1.5

# %%
df.loc[(df['Date'].dt.month==5) & (df['Date'].dt.year==2017)]['EUR'].mean()
# Out:
# 62.95527368421053

# %% [markdown]
# # Задание 2.2

# %%
# Out:
# 62.95527368421053

# %%
import numpy as np

i=pd.DataFrame({'i':df['USD']-df['USD'].shift(1)})

i.hist(bins=66,figsize=(22,11))
plt.show()

# %% [markdown]
# # Задание 2.3

# %%
df['Weekday'] = df.Date.dt.weekday.replace(
    {
        0 : u'Понедельник',
        1 : u'Вторник',
        2 : u'Среда',
        3 : u'Четверг',
        4 : u'Пятница',
        5 : u'Суббота',
        6 : u'Воскресенье'
    })

# %% [markdown]
# # Задание 2.4

# %%
df['USD'].corr(df['EUR'])
# Out:
# 0.98230892515582846
